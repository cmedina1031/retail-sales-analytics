# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("~/Downloads/Superstore_Clean_Dataset.csv")

df.head()
# Out:
#    Order Date    Sales  Profit Customer Segment Region Product Category
# 0  2023-01-09   761.59  245.91      Home Office   East        Furniture
# 1  2024-06-24  1469.35  189.93      Home Office   East        Furniture
# 2  2024-06-16   328.92  -37.56      Home Office   West  Office Supplies
# 3  2024-10-02   135.01   37.32         Consumer   East  Office Supplies
# 4  2024-03-24  1210.21  229.26        Corporate   West       Technology

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Date        1000 non-null   datetime64[ns]
#  1   Sales             1000 non-null   float64
#  2   Profit            1000 non-null   float64
#  3   Customer Segment  1000 non-null   object
#  4   Region            1000 non-null   object
#  5   Product Category  1000 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 47.0+ KB
#                 Order Date       Sales       Profit
# count                 1000  1000.00000  1000.000000
# mean   2023-07-04 04:48:00   988.09578    79.042100
# min    2022-01-01 00:00:00    29.78000  -363.220000
# 25%    2022-09-29 18:00:00   451.39000   -28.320000
# 50%    2023-07-07 00:00:00  1003.61000    45.820000
# 75%    2024-04-13 00:00:00  1506.34500   173.252500
# max    2024-12-31 00:00:00  1998.84000   667.470000
# std                    NaN   591.30391   182.628183

# %%
# create KPIs
total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()
profit_margin = total_profit / total_sales

print("Total Sales:", round(total_sales,2))
print("Total Profit:", round(total_profit,2))
print("Profit Margin:", round(profit_margin*100,2), "%")
# Out:
# Total Sales: 988095.78
# Total Profit: 79042.1
# Profit Margin: 8.0 %

# %%
region_sales = df.groupby("Region")["Sales"].sum()

region_sales.plot(kind="bar")
plt.title("Sales by Region")
plt.ylabel("Total Sales")
plt.show()

# %%
df["Month"] = df["Order Date"].dt.to_period("M")
monthly_sales = df.groupby("Month")["Sales"].sum()

monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.show()

# %%
category_profit = df.groupby("Product Category")["Profit"].sum()

category_profit.plot(kind="bar")
plt.title("Profit by Product Category")
plt.show()
